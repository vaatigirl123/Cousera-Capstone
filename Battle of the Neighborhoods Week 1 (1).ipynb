# %% [markdown]
# # The Battle of the Neighborhoods - Week 1

# %% [markdown]
# ## Introduction & Business Problem :

# %% [markdown]
# ## Problem Background:

# %% [markdown]
# In this project we will help people who are looking for renting an apartment in Vienna. If they are looking to move to Vienna they can see:
#     Which district has cheaper rent or,
#     They can choose to live in residential or commercial areas and can see for example which residential districts is best
# Or, if they already live in one of the 23 districts in Vienna they will be able to see:
#     If they are paying more than the average price for their apartment
#     If there are similar districts to theirs with lower rents

# %% [markdown]
# ## Problem Description:

# %% [markdown]
# An apartment can be expensive for many different reasons, size, location, ammeddities, and walking distance to the nearest resturant or store.
#
# 1. Location of Apartment ie which district is cheaper on average.
# 2. What areas are better to live in reisential or commercial
# 2. If already living in Vienna the costumer can see if they are overpaying
# 4. If there are similar districts with lower prices

# %% [markdown]
# ## Target Audience:

# %% [markdown]
# To recommend the best location and price for people looking to rent in Vienna

# %% [markdown]
# ## Success Criteria:

# %% [markdown]
# The success criteria of the project will be a good recommendation of Neighborhood choice to XYZ person based on location and price of apartment in that location.
